# %%
import requests

endpoint = "https://api.assemblyai.com/v2/transcript"

json = {
  "audio_url": "https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3"
}

headers = {
    "authorization": "cfcf3caf09a2463899e902628d9253db",
    "content-type": "application/json"
}

response = requests.post(endpoint, json=json, headers=headers)

print(response.json())

transcript_id=response.json()['id']
# Out:
# {'id': 'v09lhldyf-736a-40ef-9bb3-8c0896bd2e00', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'queued', 'audio_url': 'https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3', 'text': None, 'words': None, 'utterances': None, 'confidence': None, 'audio_duration': None, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': False, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': False, 'content_safety': False, 'iab_categories': False, 'content_safety_labels': {}, 'iab_categories_result': {}}
# v09lhldyf-736a-40ef-9bb3-8c0896bd2e00

# %%
endpoint = "https://api.assemblyai.com/v2/transcript/"+transcript_id

headers = {
    "authorization": "cfcf3caf09a2463899e902628d9253db",
}

response = requests.get(endpoint, headers=headers)

print(response.json())
# Out:
# {'id': 'v09lhldyf-736a-40ef-9bb3-8c0896bd2e00', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'completed', 'audio_url': 'https://s3-us-west-2.amazonaws.com/blog.assemblyai.com/audio/8-7-2018-post/7510.mp3', 'text': 'You know, demons on TV like that. And and for people to expose themselves to being rejected on TV. Or, you know, he Mi humiliated by Fear Factor or, you know.', 'words': [{'text': 'You', 'confidence': 1.0, 'end': 450, 'start': 0}, {'text': 'know,', 'confidence': 0.99, 'end': 690, 'start': 460}, {'text': 'demons', 'confidence': 0.96, 'end': 1350, 'start': 700}, {'text': 'on', 'confidence': 0.95, 'end': 1560, 'start': 1350}, {'text': 'TV', 'confidence': 0.97, 'end': 1740, 'start': 1570}, {'text': 'like', 'confidence': 1.0, 'end': 2130, 'start': 1800}, {'text': 'that.', 'confidence': 0.99, 'end': 2340, 'start': 2140}, {'text': 'And', 'confidence': 0.92, 'end': 2580, 'start': 2350}, {'text': 'and', 'confidence': 1.0, 'end': 3060, 'start': 2590}, {'text': 'for', 'confidence': 0.88, 'end': 3300, 'start': 3070}, {'text': 'people', 'confidence': 0.97, 'end': 3660, 'start': 3310}, {'text': 'to', 'confidence': 0.89, 'end': 3840, 'start': 3670}, {'text': 'expose', 'confidence': 0.98, 'end': 4530, 'start': 3850}, {'text': 'themselves', 'confidence': 0.95, 'end': 5100, 'start': 4540}, {'text': 'to', 'confidence': 1.0, 'end': 5220, 'start': 5110}, {'text': 'being', 'confidence': 0.95, 'end': 5580, 'start': 5230}, {'text': 'rejected', 'confidence': 0.95, 'end': 6060, 'start': 5590}, {'text': 'on', 'confidence': 0.98, 'end': 6240, 'start': 6070}, {'text': 'TV.', 'confidence': 0.97, 'end': 6420, 'start': 6250}, {'text': 'Or,', 'confidence': 0.95, 'end': 6840, 'start': 6600}, {'text': 'you', 'confidence': 1.0, 'end': 7350, 'start': 6840}, {'text': 'know,', 'confidence': 1.0, 'end': 7560, 'start': 7360}, {'text': 'he', 'confidence': 0.95, 'end': 7800, 'start': 7570}, {'text': 'Mi', 'confidence': 0.83, 'end': 8250, 'start': 7800}, {'text': 'humiliated', 'confidence': 0.94, 'end': 9000, 'start': 8260}, {'text': 'by', 'confidence': 0.93, 'end': 9210, 'start': 9010}, {'text': 'Fear', 'confidence': 0.94, 'end': 9630, 'start': 9220}, {'text': 'Factor', 'confidence': 0.96, 'end': 10080, 'start': 9630}, {'text': 'or,', 'confidence': 0.94, 'end': 10350, 'start': 10140}, {'text': 'you', 'confidence': 0.99, 'end': 11490, 'start': 11280}, {'text': 'know.', 'confidence': 0.96, 'end': 11700, 'start': 11500}], 'utterances': None, 'confidence': 0.957741935483871, 'audio_duration': 12, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': False, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': False, 'content_safety': False, 'iab_categories': False, 'content_safety_labels': {'status': 'unavailable', 'results': [], 'summary': {}}, 'iab_categories_result': {'status': 'unavailable', 'results': [], 'summary': {}}}
