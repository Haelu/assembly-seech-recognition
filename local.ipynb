# %%
import sys
import time
import requests
 
filename = ''
def read_file(filename, chunk_size=5242880):
    with open(filename, 'rb') as _file:
        while True:
            data = _file.read(chunk_size)
            if not data:
                break
            yield data
 
headers = {'authorization': "cfcf3caf09a2463899e902628d9253db"}
response = requests.post('https://api.assemblyai.com/v2/upload',
                         headers=headers,
                         data=read_file('spacerace.mp3'))

print(response.json());
# Out:
# {'upload_url': 'https://cdn.assemblyai.com/upload/22371d7e-c05f-48f8-8478-e065c401626f'}

# %%
endpoint = "https://api.assemblyai.com/v2/transcript"

audio_url = response.json()['upload_url']

json = {
  "audio_url": audio_url,
  "speaker_labels": True
}

headers = {
    "authorization": "cfcf3caf09a2463899e902628d9253db",
    "content-type": "application/json"
}

response = requests.post(endpoint, json=json, headers=headers)

print(response.json())
# Out:
# {'id': 'v7ye9n8x9-3f70-48b0-b455-4583f0ff0e48', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'queued', 'audio_url': 'https://cdn.assemblyai.com/upload/22371d7e-c05f-48f8-8478-e065c401626f', 'text': None, 'words': None, 'utterances': None, 'confidence': None, 'audio_duration': None, 'punctuate': True, 'format_text': True, 'dual_channel': None, 'webhook_url': None, 'webhook_status_code': None, 'speed_boost': False, 'auto_highlights_result': None, 'auto_highlights': False, 'audio_start_from': None, 'audio_end_at': None, 'word_boost': [], 'boost_param': None, 'filter_profanity': False, 'redact_pii': False, 'redact_pii_audio': False, 'redact_pii_audio_quality': None, 'redact_pii_policies': None, 'redact_pii_sub': None, 'speaker_labels': True, 'content_safety': False, 'iab_categories': False, 'content_safety_labels': {}, 'iab_categories_result': {}}

# %%
transcript_id=response.json()['id']
endpoint = "https://api.assemblyai.com/v2/transcript/"+transcript_id

headers = {
    "authorization": "cfcf3caf09a2463899e902628d9253db",
}

response = requests.get(endpoint, headers=headers)

print(response.json())
# Out:
# {'id': 'v7ye9n8x9-3f70-48b0-b455-4583f0ff0e48', 'language_model': 'assemblyai_default', 'acoustic_model': 'assemblyai_default', 'status': 'completed', 'audio_url': 'https://cdn.assemblyai.com/upload/22371d7e-c05f-48f8-8478-e065c401626f', 'text': "And I think maybe you know more about him than I do. So could you tell us a little bit about what kind of guy Richard Branson is? He's got a couple of interesting parts to his story. Number one, he never went to University. In fact, I don't think he even finished his exams when he was 16. So he's a real true entrepreneur. One of the first businesses he started was a magazine.", 'words': [{'text': 'And', 'confidence': 0.98, 'speaker': 'A', 'end': 540, 'start': 0}, {'text': 'I', 'confidence': 0.76, 'speaker': 'A', 'end': 600, 'start': 550}, {'text': 'think', 'confidence': 0.97, 'speaker': 'A', 'end': 840, 'start': 610}, {'text': 'maybe', 'confidence': 0.97, 'speaker': 'A', 'end': 1110, 'start': 850}, {'text': 'you', 'confidence': 0.98, 'speake
# ...
